# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\CODE\Notebooks\notebooks\archive\serviceDetails.csv",index_col=0)

# %%
df.head(15)
# Out:
#     customerID PhoneService     MultipleLines InternetService  \
# 1   8260-NGFNY           No  No phone service             DSL
# 2   2359-QWQUL          Yes                No     Fiber optic
# 3   6598/RFFVI          Yes                No              No
# 4   IXSTS-8780          Yes               Yes     Fiber optic
# 5   2674/MIAHT          Yes               Yes     Fiber optic
# 6   6077-BDPXA          Yes                No     Fiber optic
# 7   7929/SKFGK          Yes               Yes     Fiber optic
# 8   7547-EKNFS          Yes               Yes     Fiber optic
# 9   5854-KSRBJ          Yes               Yes              No
# 10  5054-IEXZT          Yes                No     Fiber optic
# 11  1877-HKBQX          Yes                No             DSL
# 12  7235-NXZCP          Yes               Yes     Fiber optic
# 13  3325-FUYCG          Yes               Yes     Fiber optic
# 14  2452-MRMZF          Yes               Yes              No
# ...

# %%
mod_df = df.copy()

# %%
mod_df.head(15)
# Out:
#     customerID PhoneService     MultipleLines InternetService  \
# 1   8260-NGFNY           No  No phone service             DSL
# 2   2359-QWQUL          Yes                No     Fiber optic
# 3   6598/RFFVI          Yes                No              No
# 4   IXSTS-8780          Yes               Yes     Fiber optic
# 5   2674/MIAHT          Yes               Yes     Fiber optic
# 6   6077-BDPXA          Yes                No     Fiber optic
# 7   7929/SKFGK          Yes               Yes     Fiber optic
# 8   7547-EKNFS          Yes               Yes     Fiber optic
# 9   5854-KSRBJ          Yes               Yes              No
# 10  5054-IEXZT          Yes                No     Fiber optic
# 11  1877-HKBQX          Yes                No             DSL
# 12  7235-NXZCP          Yes               Yes     Fiber optic
# 13  3325-FUYCG          Yes               Yes     Fiber optic
# 14  2452-MRMZF          Yes               Yes              No
# ...

# %%
df = df.map(lambda x: 1 if x == "Yes" else (0 if x == "No" else x))

# %%
df.head(25)
# Out:
#     customerID  PhoneService     MultipleLines InternetService  \
# 1   8260-NGFNY             0  No phone service             DSL
# 2   2359-QWQUL             1                 0     Fiber optic
# 3   6598/RFFVI             1                 0               0
# 4   IXSTS-8780             1                 1     Fiber optic
# 5   2674/MIAHT             1                 1     Fiber optic
# 6   6077-BDPXA             1                 0     Fiber optic
# 7   7929/SKFGK             1                 1     Fiber optic
# 8   7547-EKNFS             1                 1     Fiber optic
# 9   5854-KSRBJ             1                 1               0
# 10  5054-IEXZT             1                 0     Fiber optic
# 11  1877-HKBQX             1                 0             DSL
# 12  7235-NXZCP             1                 1     Fiber optic
# 13  3325-FUYCG             1                 1     Fiber optic
# 14  2452-MRMZF             1                 1               0
# ...

# %%
df = mod_df.copy()

# %%
mod_df.head(100)
# Out:
#      customerID PhoneService     MultipleLines InternetService  \
# 1    8260-NGFNY           No  No phone service             DSL
# 2    2359-QWQUL          Yes                No     Fiber optic
# 3    6598/RFFVI          Yes                No              No
# 4    IXSTS-8780          Yes               Yes     Fiber optic
# 5    2674/MIAHT          Yes               Yes     Fiber optic
# ..          ...          ...               ...             ...
# 96   3606-TWKGI          Yes               Yes     Fiber optic
# 97   2845-KDHVX          Yes                No             DSL
# 98   9927-DSWDF          Yes                No     Fiber optic
# 99   2272-JKMSI          Yes               Yes     Fiber optic
# 100  5055-MGMGF          Yes               Yes     Fiber optic
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 1                     No                   No                   No
# 2                    Yes                   No                  Yes
# ...

# %%
df.head(100)
# Out:
#      customerID PhoneService     MultipleLines InternetService  \
# 1    8260-NGFNY           No  No phone service             DSL
# 2    2359-QWQUL          Yes                No     Fiber optic
# 3    6598/RFFVI          Yes                No              No
# 4    IXSTS-8780          Yes               Yes     Fiber optic
# 5    2674/MIAHT          Yes               Yes     Fiber optic
# ..          ...          ...               ...             ...
# 96   3606-TWKGI          Yes               Yes     Fiber optic
# 97   2845-KDHVX          Yes                No             DSL
# 98   9927-DSWDF          Yes                No     Fiber optic
# 99   2272-JKMSI          Yes               Yes     Fiber optic
# 100  5055-MGMGF          Yes               Yes     Fiber optic
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 1                     No                   No                   No
# 2                    Yes                   No                  Yes
# ...

# %%
df.head(15)
# Out:
#     customerID PhoneService     MultipleLines InternetService  \
# 1   8260-NGFNY           No  No phone service             DSL
# 2   2359-QWQUL          Yes                No     Fiber optic
# 3   6598/RFFVI          Yes                No              No
# 4   IXSTS-8780          Yes               Yes     Fiber optic
# 5   2674/MIAHT          Yes               Yes     Fiber optic
# 6   6077-BDPXA          Yes                No     Fiber optic
# 7   7929/SKFGK          Yes               Yes     Fiber optic
# 8   7547-EKNFS          Yes               Yes     Fiber optic
# 9   5854-KSRBJ          Yes               Yes              No
# 10  5054-IEXZT          Yes                No     Fiber optic
# 11  1877-HKBQX          Yes                No             DSL
# 12  7235-NXZCP          Yes               Yes     Fiber optic
# 13  3325-FUYCG          Yes               Yes     Fiber optic
# 14  2452-MRMZF          Yes               Yes              No
# ...

# %%
len(df["customerID"].unique())
# Out:
# 250

# %%
df.duplicated(subset=["customerID"])
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 247    False
# 248    False
# 249    False
# 250    False
# 251     True
# Length: 251, dtype: bool

# %%
demodetail = pd.read_csv(r"D:\CODE\Notebooks\notebooks\archive\demoDetails.csv")

# %%
demodetail[demodetail.duplicated(subset=["customerID"],keep=False)]
# Out:
#      Unnamed: 0  customerID gender  SeniorCitizen Partner Dependents
# 45           46  9067-SQTNS   Male            0.0     Yes        Yes
# 250         251  9067-SQTNS   Male            0.0     Yes        Yes

# %%
df.head(15)
# Out:
#     customerID PhoneService     MultipleLines InternetService  \
# 1   8260-NGFNY           No  No phone service             DSL
# 2   2359-QWQUL          Yes                No     Fiber optic
# 3   6598/RFFVI          Yes                No              No
# 4   IXSTS-8780          Yes               Yes     Fiber optic
# 5   2674/MIAHT          Yes               Yes     Fiber optic
# 6   6077-BDPXA          Yes                No     Fiber optic
# 7   7929/SKFGK          Yes               Yes     Fiber optic
# 8   7547-EKNFS          Yes               Yes     Fiber optic
# 9   5854-KSRBJ          Yes               Yes              No
# 10  5054-IEXZT          Yes                No     Fiber optic
# 11  1877-HKBQX          Yes                No             DSL
# 12  7235-NXZCP          Yes               Yes     Fiber optic
# 13  3325-FUYCG          Yes               Yes     Fiber optic
# 14  2452-MRMZF          Yes               Yes              No
# ...

# %%
acdetails = pd.read_csv(r"D:\CODE\Notebooks\notebooks\archive\acDetails.txt",sep="\t")

# %%
acdetails.shape
# Out:
# (251, 7)

# %%
acdetails.head(15)
# Out:
#     customerID tenure        Contract PaperlessBilling  \
# 1   8260-NGFNY    One  Month-to-month               No
# 2   2359-QWQUL     39        One year              Yes
# 3   6598/RFFVI      2        One year               No
# 4   IXSTS-8780      6  Month-to-month              Yes
# 5   2674/MIAHT   Four  Month-to-month              Yes
# 6   6077-BDPXA      3  Month-to-month              Yes
# 7   7929/SKFGK     70        Two year               No
# 8   7547-EKNFS     42  Month-to-month              Yes
# 9   5854-KSRBJ     70        Two year               No
# 10  5054-IEXZT    One  Month-to-month              Yes
# 11  1877-HKBQX     11        One year              Yes
# 12  7235-NXZCP      2  Month-to-month              Yes
# 13  3325-FUYCG     28        One year               No
# 14  2452-MRMZF     72        Two year              Yes
# 15  9184-GALIL     38  Month-to-month               No
#
#                 PaymentMethod  MonthlyCharges  TotalCharges
# ...

# %%
acdetails.describe()
# Out:
#        MonthlyCharges  TotalCharges
# count      241.000000    236.000000
# mean        63.515975   2302.071186
# std         30.792143   2289.409871
# min          3.500000     18.850000
# 25%         33.150000    448.500000
# 50%         70.750000   1336.350000
# 75%         89.150000   3845.987500
# max        115.100000   8337.450000

# %%
acdetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries, 1 to 251
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        251 non-null    object
#  1   tenure            251 non-null    object
#  2   Contract          251 non-null    object
#  3   PaperlessBilling  251 non-null    object
#  4   PaymentMethod     251 non-null    object
#  5   MonthlyCharges    241 non-null    float64
#  6   TotalCharges      236 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 15.7+ KB

# %%
acdetails.head(8)
# Out:
#    customerID tenure        Contract PaperlessBilling  \
# 1  8260-NGFNY    One  Month-to-month               No
# 2  2359-QWQUL     39        One year              Yes
# 3  6598/RFFVI      2        One year               No
# 4  IXSTS-8780      6  Month-to-month              Yes
# 5  2674/MIAHT   Four  Month-to-month              Yes
# 6  6077-BDPXA      3  Month-to-month              Yes
# 7  7929/SKFGK     70        Two year               No
# 8  7547-EKNFS     42  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 1               Mailed check           25.20         25.20
# 2    Credit card (automatic)          104.70       4134.85
# 3    Credit card (automatic)           19.30         28.30
# 4           Electronic check           90.10        521.30
# 5               Mailed check           80.30        324.20
# 6           Electronic check           70.15        194.20
# 7    Credit card (automatic)          114.30       8244.30
# ...

# %%
acdetails.isna().sum()
# Out:
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# dtype: int64

# %%
acdetails[acdetails.isna().any(axis=1)]#list the cols with missing values
# Out:
#      customerID tenure        Contract PaperlessBilling  \
# 14   2452-MRMZF     72        Two year              Yes
# 42   4910-AQFFX      9  Month-to-month              Yes
# 51   6652-YFFJO     11  Month-to-month              Yes
# 65   7605-BDWDC     31        Two year              Yes
# 67   4759-TRPLW   1008  Month-to-month               No
# 77   8148-BPLZQ     34  Month-to-month              Yes
# 89   5919-TMRGD    One  Month-to-month              Yes
# 90   5201-CBWYG     62        One year               No
# 95   1785-BPHTP     28  Month-to-month               No
# 102  9392-XBGTD     27        Two year               No
# 116  5712-AHQNN     43  Month-to-month              Yes
# 119  3694-GLTJM      5  Month-to-month              Yes
# 131  4682-BLBUC     44        One year              Yes
# 132  3258-ZKPAI     72        Two year              Yes
# 133  3261-CQXOL     71        Two year               No
# 137  6447-GORXK     31  Month-to-month               No
# ...

# %%
servicedetails = pd.read_csv(r"D:\CODE\Notebooks\notebooks\archive\serviceDetails.csv",index_col=0)

# %%
demodetails = pd.read_csv(r"D:\CODE\Notebooks\notebooks\archive\demoDetails.csv",index_col=0)

# %%
servicedetails.isna().sum()
# Out:
# customerID          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
demodetails.isna().sum()
# Out:
# customerID       0
# gender           0
# SeniorCitizen    5
# Partner          0
# Dependents       0
# dtype: int64

# %%
demodetails[demodetails.isna().any(axis=1)]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents
# 43   7359-SSBJK  Female            NaN      No         No
# 69   8087-LGYHQ    Male            NaN      No         No
# 136  0601-WZHJF    Male            NaN     Yes         No
# 192  7017-VFULY  Female            NaN     Yes         No
# 219  8413-VONUO    Male            NaN      No         No

# %%
demodetails[demodetails.duplicated(keep=False)]
# Out:
#      customerID gender  SeniorCitizen Partner Dependents
# 46   9067-SQTNS   Male            0.0     Yes        Yes
# 251  9067-SQTNS   Male            0.0     Yes        Yes

# %%
acdetails[acdetails.duplicated(keep=False)]
# Out:
#      customerID tenure  Contract PaperlessBilling              PaymentMethod  \
# 46   9067-SQTNS     44  One year               No  Bank transfer (automatic)
# 251  9067-SQTNS     44  One year               No  Bank transfer (automatic)
#
#      MonthlyCharges  TotalCharges
# 46             20.6         926.0
# 251            20.6         926.0

# %%
servicedetails[servicedetails.duplicated(keep=False)]
# Out:
#      customerID PhoneService MultipleLines InternetService OnlineSecurity  \
# 46   9067-SQTNS          Yes            No              No            Yes
# 251  9067-SQTNS          Yes            No              No            Yes
#
#     OnlineBackup     DeviceProtection          TechSupport StreamingTV  \
# 46           Yes  No internet service  No internet service         Yes
# 251          Yes  No internet service  No internet service         Yes
#
#          StreamingMovies Churn
# 46   No internet service    No
# 251  No internet service    No

# %%
servicedetails.drop_duplicates(inplace=True)

# %%
servicedetails.iloc[45]
# Out:
# customerID                   9067-SQTNS
# PhoneService                        Yes
# MultipleLines                        No
# InternetService                      No
# OnlineSecurity                      Yes
# OnlineBackup                        Yes
# DeviceProtection    No internet service
# TechSupport         No internet service
# StreamingTV                         Yes
# StreamingMovies     No internet service
# Churn                                No
# Name: 46, dtype: object

# %%
demodetails.drop_duplicates(inplace=True)

# %%
acdetails[acdetails.duplicated(keep=False)]
# Out:
#      customerID tenure  Contract PaperlessBilling              PaymentMethod  \
# 46   9067-SQTNS     44  One year               No  Bank transfer (automatic)
# 251  9067-SQTNS     44  One year               No  Bank transfer (automatic)
#
#      MonthlyCharges  TotalCharges
# 46             20.6         926.0
# 251            20.6         926.0

# %%
acdetails.drop_duplicates(inplace=True)

# %%
acdetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 1 to 250
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        250 non-null    object
#  1   tenure            250 non-null    object
#  2   Contract          250 non-null    object
#  3   PaperlessBilling  250 non-null    object
#  4   PaymentMethod     250 non-null    object
#  5   MonthlyCharges    240 non-null    float64
#  6   TotalCharges      235 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 15.6+ KB

# %%
acdetails["customerID"].equals(demodetails["customerID"])
# Out:
# True

# %%
churn = pd.merge(demodetails,acdetails,on="customerID")

# %%
churn.head(25)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents tenure  \
# 0   8260-NGFNY  Female            0.0      No         No    One
# 1   2359-QWQUL  Female            0.0     Yes         No     39
# 2   6598/RFFVI    Male            0.0      No         No      2
# 3   IXSTS-8780  Female            0.0      No         No      6
# 4   2674/MIAHT  Female            0.0      No         No   Four
# 5   6077-BDPXA  Female            0.0      No         No      3
# 6   7929/SKFGK    Male            0.0     Yes         No     70
# 7   7547-EKNFS    Male            0.0     Yes         No     42
# 8   5854-KSRBJ    Male            0.0     Yes        Yes     70
# 9   5054-IEXZT    Male            0.0      No        Yes    One
# 10  1877-HKBQX  Female            0.0      No         No     11
# 11  7235-NXZCP    Male            1.0      No         No      2
# 12  3325-FUYCG    Male            0.0     Yes        Yes     28
# 13  2452-MRMZF  Female            1.0     Yes         No     72
# ...

# %%
churn = pd.merge(churn,servicedetails,on="customerID")

# %%
churn1 = churn.copy()

# %%
churn1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure  \
# 0  8260-NGFNY  Female            0.0      No         No    One
# 1  2359-QWQUL  Female            0.0     Yes         No     39
# 2  6598/RFFVI    Male            0.0      No         No      2
# 3  IXSTS-8780  Female            0.0      No         No      6
# 4  2674/MIAHT  Female            0.0      No         No   Four
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month               No             Mailed check            25.2
# 1        One year              Yes  Credit card (automatic)           104.7
# 2        One year               No  Credit card (automatic)            19.3
# 3  Month-to-month              Yes         Electronic check            90.1
# 4  Month-to-month              Yes             Mailed check            80.3
#
#    ...  PhoneService     MultipleLines InternetService       OnlineSecurity  \
# ...

# %%
churn1[churn1.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
churn1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        250 non-null    object
#  1   gender            250 non-null    object
#  2   SeniorCitizen     245 non-null    float64
#  3   Partner           250 non-null    object
#  4   Dependents        250 non-null    object
#  5   tenure            250 non-null    object
#  6   Contract          250 non-null    object
#  7   PaperlessBilling  250 non-null    object
#  8   PaymentMethod     250 non-null    object
#  9   MonthlyCharges    240 non-null    float64
#  10  TotalCharges      235 non-null    float64
#  11  PhoneService      250 non-null    object
#  12  MultipleLines     250 non-null    object
#  13  InternetService   250 non-null    object
#  14  OnlineSecurity    250 non-null    object
#  15  OnlineBackup      250 non-null    object
# ...

# %%
churn1.iloc[:,1]
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4      Female
#         ...
# 245      Male
# 246      Male
# 247    Female
# 248    Female
# 249      Male
# Name: gender, Length: 250, dtype: object

# %%
churn1["gender"] = churn1['gender'].astype('category')

# %%
churn1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        250 non-null    object
#  1   gender            250 non-null    category
#  2   SeniorCitizen     245 non-null    float64
#  3   Partner           250 non-null    object
#  4   Dependents        250 non-null    object
#  5   tenure            250 non-null    object
#  6   Contract          250 non-null    object
#  7   PaperlessBilling  250 non-null    object
#  8   PaymentMethod     250 non-null    object
#  9   MonthlyCharges    240 non-null    float64
#  10  TotalCharges      235 non-null    float64
#  11  PhoneService      250 non-null    object
#  12  MultipleLines     250 non-null    object
#  13  InternetService   250 non-null    object
#  14  OnlineSecurity    250 non-null    object
#  15  OnlineBackup      250 non-null    object
# ...

# %%
churn1["tenure"].unique()
# Out:
# array(['One', '39', '2', '6', 'Four', '3', '70', '42', '11', '28', '72',
#        '38', '64', '30', '49', '10', '57', '16', '54', '69', '25', '71',
#        '17', '21', '65', '51', '62', '9', '13', '44', '8', '68', '971',
#        '63', '61', '48', '5', '32', '37', '31', '1008', '46', '36', '18',
#        '34', '66', '22', '43', '29', '994', '47', '27', '55', '58', '59',
#        '56', '52', '7', '12', '19', '45', '14', '53', '992', '15', '41',
#        '40', '969', '67', '964', '50'], dtype=object)

# %%
churn1["SeniorCitizen"].unique()
# Out:
# array([ 0.,  1., nan])

# %%
churn1.groupby("tenure")["tenure"].count() #include NaN
# Out:
# tenure
# 10       5
# 1008     1
# 11       3
# 12       1
# 13       3
#         ..
# 971      1
# 992      1
# 994      1
# Four     9
# One     20
# Name: tenure, Length: 71, dtype: int64

# %%
churn1.groupby("tenure")["tenure"].size() #does not include NaN
# Out:
# tenure
# 10       5
# 1008     1
# 11       3
# 12       1
# 13       3
#         ..
# 971      1
# 992      1
# 994      1
# Four     9
# One     20
# Name: tenure, Length: 71, dtype: int64

# %%
churn1.groupby("SeniorCitizen")["SeniorCitizen"].count()
# Out:
# SeniorCitizen
# 0.0    211
# 1.0     34
# Name: SeniorCitizen, dtype: int64

# %%
churn1[churn1.isna().any(axis=1)]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents tenure  \
# 13   2452-MRMZF  Female            1.0     Yes         No     72
# 41   4910-AQFFX    Male            0.0     Yes        Yes      9
# 42   7359-SSBJK  Female            NaN      No         No     64
# 50   6652-YFFJO  Female            0.0      No         No     11
# 64   7605-BDWDC  Female            0.0      No         No     31
# 66   4759-TRPLW    Male            0.0      No         No   1008
# 68   8087-LGYHQ    Male            NaN      No         No      9
# 76   8148-BPLZQ    Male            0.0      No         No     34
# 88   5919-TMRGD  Female            0.0      No        Yes    One
# 89   5201-CBWYG    Male            0.0     Yes        Yes     62
# 94   1785-BPHTP    Male            0.0     Yes        Yes     28
# 101  9392-XBGTD    Male            0.0      No        Yes     27
# 115  5712-AHQNN  Female            0.0      No         No     43
# ...

# %%
tmp = churn1["SeniorCitizen"].isna()

# %%
tmp.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: SeniorCitizen, dtype: bool

# %%
tmp = tmp.to_frame()

# %%
tmp.shape
# Out:
# (250, 1)

# %%
tmp.head(10)
# Out:
#    SeniorCitizen
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False

# %%
churn1.MonthlyCharges.mode()
# Out:
# 0    8.0
# Name: MonthlyCharges, dtype: float64

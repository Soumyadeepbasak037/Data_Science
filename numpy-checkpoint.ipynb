# %%
import numpy as np

# %%
arr = [1,2,3,4,5,6]

# %%
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numpy_arr = np.array(arr)

# %%
print(type(numpy_arr))
# Out:
# <class 'numpy.ndarray'>

# %%
row1 = [1,2,3]
row2 = [3,4,5]

# %%
arr2d = np.array([[1, 2], [4, 5]])
arr2d2 = np.array([[1, 2], [4, 5]])

# %%
print(np.multiply(arr2d,arr2d2))
# Out:
# [[ 1  4]
#  [16 25]]

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\CODE\Notebooks\notebooks\archive\survey_results_responses.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df.head(15)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
print("hello world")
# Out:
# hello world

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df[['Employment','Age']]
# Out:
#                                               Employment              Age
# 0      Independent contractor, freelancer, or self-em...  25-34 years old
# 1                                     Student, full-time  18-24 years old
# 2                                     Student, full-time  18-24 years old
# 3                                     Employed full-time  35-44 years old
# 4      Independent contractor, freelancer, or self-em...  25-34 years old
# ...                                                  ...              ...
# 83434                                 Employed full-time  25-34 years old
# 83435  Independent contractor, freelancer, or self-em...  18-24 years old
# 83436                                 Employed full-time  25-34 years old
# 83437                                 Employed full-time  25-34 years old
# 83438                                 Employed full-time  18-24 years old
#
# [83439 rows x 2 columns]

# %%
for index, row in df.iterrows():
    print("Age:"+str(row['Age']))
# Out:
# Age:25-34 years old
# Age:18-24 years old
# Age:18-24 years old
# Age:35-44 years old
# Age:25-34 years old
# Age:18-24 years old
# Age:Prefer not to say
# Age:18-24 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:Prefer not to say
# Age:45-54 years old
# Age:Under 18 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:45-54 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:18-24 years old
# Age:Under 18 years old
# Age:25-34 years old
# Age:35-44 years old
# Age:35-44 years old
# Age:25-34 years old
# Age:45-54 years old
# Age:25-34 years old
# Age:35-44 years old
# Age:Prefer not to say
# Age:25-34 years old
# Age:25-34 years old
# Age:18-24 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:18-24 years old
# Age:35-44 years old
# Age:18-24 years old
# Age:18-24 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:25-34 years old
# Age:18-24 years old
# ...

# %%
print(type(df['Age']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
print(df.columns)
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OperatingSystem', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Accessibility', 'MentalHealth',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df["Country"]
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
df[(df["OperatingSystem"] == 'Linux-based') & (df["Country"] == 'India')][['Country', 'Employment', 'LearnCode', 'OperatingSystem']]
# print(len(res))
# Out:
#       Country                                         Employment  \
# 39      India                                 Student, part-time
# 59      India                                 Student, full-time
# 98      India                                 Employed full-time
# 255     India                 Not employed, but looking for work
# 297     India                                 Student, full-time
# 367     India                                 Employed full-time
# 378     India                                 Employed full-time
# 418     India                                 Student, full-time
# 427     India                 Not employed, but looking for work
# 434     India                                 Employed full-time
# 445     India                                 Student, full-time
# 511     India                                 Employed full-time
# 513     India  Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_rows', None)  # Show all rows

# %%
df.loc[(df["Country"] == "India") & (df["OperatingSystem"] == "Linux-based"),["Country","Employment","OperatingSystem"]]
# Out:
#       Country                                         Employment  \
# 39      India                                 Student, part-time
# 59      India                                 Student, full-time
# 98      India                                 Employed full-time
# 255     India                 Not employed, but looking for work
# 297     India                                 Student, full-time
# 367     India                                 Employed full-time
# 378     India                                 Employed full-time
# 418     India                                 Student, full-time
# 427     India                 Not employed, but looking for work
# 434     India                                 Employed full-time
# 445     India                                 Student, full-time
# 511     India                                 Employed full-time
# 513     India  Independent contractor, freelancer, or self-em...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OperatingSystem', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Accessibility', 'MentalHealth',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['id'] = df.index

# %%
df.head
# Out:
# <bound method NDFrame.head of        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OperatingSystem', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Accessibility', 'MentalHealth',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly', 'id'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
df['UK_Country'].isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 83434     True
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: UK_Country, Length: 83439, dtype: bool

# %%
df.memory_usage()
# Out:
# Index                              132
# ResponseId                      667512
# MainBranch                      667512
# Employment                      667512
# Country                         667512
# US_State                        667512
# UK_Country                      667512
# EdLevel                         667512
# Age1stCode                      667512
# LearnCode                       667512
# YearsCode                       667512
# YearsCodePro                    667512
# DevType                         667512
# OrgSize                         667512
# Currency                        667512
# CompTotal                       667512
# CompFreq                        667512
# LanguageHaveWorkedWith          667512
# LanguageWantToWorkWith          667512
# DatabaseHaveWorkedWith          667512
# DatabaseWantToWorkWith          667512
# PlatformHaveWorkedWith          667512
# PlatformWantToWorkWith          667512
# WebframeHaveWorkedWith          667512
# ...

# %%
df.iloc[1,3]
# Out:
# 'Netherlands'

# %%
print(df.dtypes)
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
df.shape
# Out:
# (83439, 49)

# %%
df.dtypes.value_counts()
# Out:
# object     45
# int64       2
# float64     2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
import numpy as np

# %%
print(np.unique(df['Currency'].astype(str)))
# Out:
# ['AED United Arab Emirates dirham' 'AFN\tAfghan afghani'
#  'ALL\tAlbanian lek' 'AMD\tArmenian dram'
#  'ANG Netherlands Antillean guilder' 'AOA\tAngolan kwanza'
#  'ARS\tArgentine peso' 'AUD\tAustralian dollar' 'AWG\tAruban florin'
#  'AZN\tAzerbaijan manat' 'BAM\tBosnia and Herzegovina convertible mark'
#  'BBD\tBarbadian dollar' 'BDT\tBangladeshi taka' 'BGN\tBulgarian lev'
#  'BHD\tBahraini dinar' 'BIF\tBurundi franc' 'BMD\tBermudian dollar'
#  'BOB\tBolivian boliviano' 'BRL\tBrazilian real' 'BSD\tBahamian dollar'
#  'BTN\tBhutanese ngultrum' 'BWP\tBotswana pula' 'BYN\tBelarusian ruble'
#  'BZD\tBelize dollar' 'CAD\tCanadian dollar' 'CDF\tCongolese franc'
#  'CHF\tSwiss franc' 'CLP\tChilean peso' 'CNY\tChinese Yuan Renminbi'
#  'COP\tColombian peso' 'CRC\tCosta Rican colon' 'CUP\tCuban peso'
#  'CVE\tCape Verdean escudo' 'CZK\tCzech koruna' 'DJF\tDjiboutian franc'
#  'DKK\tDanish krone' 'DOP\tDominican peso' 'DZD\tAlgerian dinar'
# ...

# %%
df['Age'].dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Age'].dtypes
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EdLevel                           313
# Age1stCode                        196
# LearnCode                         476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# CompTotal                       36256
# CompFreq                        31289
# LanguageHaveWorkedWith           1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# ...

# %%
df.isna().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EdLevel                           313
# Age1stCode                        196
# LearnCode                         476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# CompTotal                       36256
# CompFreq                        31289
# LanguageHaveWorkedWith           1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OperatingSystem', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Accessibility', 'MentalHealth',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
for i in range(0,len(df['US_State'])):
    if pd.isna(df['US_State'][i]):
        df["US_State_NaN"] = True
    else:
        df["US_State_NaN"] = False

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
df.groupby("Gender")["Gender"].count()
# Out:
# Gender
# Man                                                                                   74817
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:             11
# Man;Or, in your own words:                                                              268
# Man;Woman                                                                                41
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              21
# Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:       17
# Man;Woman;Or, in your own words:                                                          1
# Non-binary, genderqueer, or gender non-conforming                                       690
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
df.groupby("Gender")["ConvertedCompYearly"].sum()
# Out:
# Gender
# Man                                                                                   5.002689e+09
# Man;Non-binary, genderqueer, or gender non-conforming                                 6.004969e+07
# Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:          1.933600e+05
# Man;Or, in your own words:                                                            9.837687e+06
# Man;Woman                                                                             7.565400e+05
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                           4.371230e+05
# Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:    3.538490e+05
# Man;Woman;Or, in your own words:                                                      6.588000e+03
# Non-binary, genderqueer, or gender non-conforming                                     5.254341e+07
# ...

# %%
gen = []
for i in range(len(df["Gender"])):
    if df["Gender"][i] not in gen:
        gen.append(df["Gender"][i])
print(gen)
# Out:
# ['Man', 'Prefer not to say', 'Woman', 'Non-binary, genderqueer, or gender non-conforming', 'Man;Or, in your own words:', nan, 'Woman;Non-binary, genderqueer, or gender non-conforming', 'Man;Non-binary, genderqueer, or gender non-conforming', 'Or, in your own words:', 'Man;Woman', 'Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:', 'Non-binary, genderqueer, or gender non-conforming;Or, in your own words:', 'Woman;Or, in your own words:', 'Man;Woman;Non-binary, genderqueer, or gender non-conforming', 'Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:', 'Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:', 'Man;Woman;Or, in your own words:']

# %%
df.count()
# Out:
# ResponseId                      83439
# MainBranch                      83439
# Employment                      83323
# Country                         83439
# US_State                        14920
# UK_Country                       4418
# EdLevel                         83126
# Age1stCode                      83243
# LearnCode                       82963
# YearsCode                       81641
# YearsCodePro                    61216
# DevType                         66484
# OrgSize                         60726
# Currency                        61080
# CompTotal                       47183
# CompFreq                        52150
# LanguageHaveWorkedWith          82357
# LanguageWantToWorkWith          76821
# DatabaseHaveWorkedWith          69546
# DatabaseWantToWorkWith          58299
# PlatformHaveWorkedWith          52135
# PlatformWantToWorkWith          41619
# WebframeHaveWorkedWith          61707
# WebframeWantToWorkWith          52095
# MiscTechHaveWorkedWith          47055
# ...

# %%
df.groupby("OperatingSystem").size()
# Out:
# OperatingSystem
# BSD                                    146
# Linux-based                          21088
# MacOS                                20984
# Other (please specify):                575
# Windows                              37758
# Windows Subsystem for Linux (WSL)     2743
# dtype: int64

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OperatingSystem', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Accessibility', 'MentalHealth',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')
